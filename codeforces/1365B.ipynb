# %%
t = int(input())
n = int(input())
a = list(map(int,input().split()))
b =list(map(int,input().split()))
c = sorted(a)
for i in range(n):
  if a[i] != c[i]:

# %%
t = int(input())
for _ in range(t):
  n = int(input())
  a = list(map(int,input().split()))
  b =list(map(int,input().split()))
  c = sorted(a)
  if a == c:
    print('YES')
  elif 0 in b and 1 in b:
    print('YES')
  else:
    print('NO')
